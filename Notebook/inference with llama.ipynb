# %%
# !pip install groq
# !pip install anthropic
#!pip install openai
# !pip install llamaapi
#!pip install -q -U google-generativeai

# %%
#export ANTHROPIC_API_KEY='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'

# %%
# from huggingface_hub import login
# login("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")

# %%
#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
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
from torch import cuda, bfloat16
import pandas as pd
import os
#from groq import Groq
from google.api_core.exceptions import InternalServerError
#import openai
import google.generativeai as genai
from llamaapi import LlamaAPI
import json
# import os
# openai.api_key = "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"

# %%
# from openai import OpenAI

# openai.api_key ='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'
llama = LlamaAPI("7d20bd77-6ed6-4861-a3ba-6521768d3f62")
#genai.configure(api_key="AIzaSyBOR6r87lI_HSv0-GEy5Bzr74uBxtYZAWY")

# %%
# Load the CSV file
csv_file_path = '/kaggle/input/dataset-for-hate-speech/Bangla Hate Speech Dataset - Dataset_Bangla_HateSpeech.csv'  # Replace with your CSV file path
df = pd.read_csv(csv_file_path, encoding='utf-8')
#, encoding='ISO-8859-1'

# %%
df.head()

# %%
# import requests
# import json

# # Define API key and endpoint
# API_KEY = "7d20bd77-6ed6-4861-a3ba-6521768d3f62"  # Replace with your actual key
# BASE_URL = "https://api.llama-api.com/v1/chat/completions"  # Correct endpoint

# # Request payload
# payload = {
#     "model": "gemma2-9b",  # Ensure this model is available in the Llama API
#     "messages": [
#         {"role": "system", "content": "You are a helpful math tutor. Guide the user through the solution step by step."},
#         {"role": "user", "content": "how can I solve 8x + 7 = -23"}
#     ],
#     "temperature": 0.7,
#     "max_tokens": 100
# }

# # API request headers
# headers = {
#     "Authorization": f"Bearer {API_KEY}",
#     "Content-Type": "application/json"
# }

# # Make API call
# response = requests.post(BASE_URL, headers=headers, json=payload)

# # Handle response
# if response.status_code == 200:
#     chat_completion = response.json()
#     print("Response:", json.dumps(chat_completion, indent=2))
# else:
#     print(f"Error {response.status_code}: {response.text}")  # Debugging

# %%
#model = genai.GenerativeModel("gemini-2.0-flash-lite")

# %%
# def generate_ai_label(statement, context):
#     label_set = ["Sexual Harassments", "Offensive", "Violence", "Harmful", "Propaganda", "Not Hateful"]
#     messages = f"You are an expert Hate Speech annotator in Bengali with an identity of {context}. Annotate the following text with only one best-suited label from the label set {label_set} with no explanation: [{statement}]"

#     try:
#         response = model.generate_content(messages)

#         # Debugging: Print the raw response structure
#         print("Raw Response:", response)

#         # Ensure there is a valid response
#         if not response or not response.candidates:
#             print("Warning: Empty response received.")
#             return "Error"

#         # Check if `parts` exist
#         if not response.candidates[0].content.parts:
#             print("Warning: No content parts in response.")
#             return "Error"

#         # Extract the text response safely
#         rr = response.candidates[0].content.parts[0].text.strip()
#         print("Generated Label:", rr)

#         return rr

#     except Exception as e:
#         print(f"An error occurred: {str(e)}")
#         return "Error"

# %%
# from transformers import AutoModelForCausalLM, AutoTokenizer
# from huggingface_hub import login

# # Log in to Hugging Face API
# login(token="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")

# Define model name
# model_name = "meta-llama/Llama-3.1-8B"

# # Load tokenizer and model with authentication
# tokenizer = AutoTokenizer.from_pretrained(model_name, token="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")
# model = AutoModelForCausalLM.from_pretrained(
#     model_name, 
#     token="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",
#     torch_dtype="auto",
#     device_map="auto"
# )

# print("Model Loaded Successfully!")

# %%
# import torch
# from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# # Load Llama 3.1 8B model from Hugging Face
# model_name = "meta-llama/Llama-3.1-8B"

# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = AutoModelForCausalLM.from_pretrained(
#     model_name, 
#     torch_dtype=torch.float16, 
#     device_map="auto"
# )

# # Create a text generation pipeline
# generator = pipeline("text-generation", model=model, tokenizer=tokenizer)

# %%
# def generate_ai_label(statement, context):
#     label_set = ["Sexual Harassments", "Offensive", "Violence", "Harmful", "Propaganda", "Not Hateful"]
    
#     prompt = f"""
#     You are an expert Hate Speech annotator in Bengali with an identity of {context}. 
#     Annotate the following text with only one best-suited label from the label set {label_set} 
#     with no explanation. Output only one label for this statement: [{statement}]
#     """

#     # Generate the response from the Llama 3.1 8B model
#     response = generator(prompt, max_new_tokens=20, temperature=0, do_sample=False)



#     # Extract response text
#     rr = response[0]["generated_text"].strip()

#     # Filter out only valid labels from response
#     selected_label = next((label for label in label_set if label.lower() in rr.lower()), "Not Hateful")
    
#     print(selected_label)
#     return selected_label


# # Wrapper functions with row handling
# def generate_ai_label_palm_with_row(statement, context, row_number):
#     print(f"Processing row {row_number} with statement: {statement}")
#     return generate_ai_label(statement, context)


# # Retry mechanism with error handling
# import time

# def generate_ai_label_palm_with_retry(statement, context, row_number, retries=1, delay=3):
#     for attempt in range(retries):
#         try:
#             return generate_ai_label_palm_with_row(statement, context, row_number)
#         except Exception as e:
#             print(f"Error encountered: {str(e)}")
#             if attempt < retries - 1:
#                 backoff_time = delay * (2 ** attempt)
#                 print(f"Retrying in {backoff_time} seconds...")
#                 time.sleep(backoff_time)
#             else:
#                 print("Max retries reached. Unable to complete the request.")
#                 return "Error"

# %%
# from transformers import AutoTokenizer, Gemma2ForSequenceClassification
# import torch

# # Load model and tokenizer
# model_name = "google/gemma-2-9b"  # Replace with the actual model checkpoint
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = Gemma2ForSequenceClassification.from_pretrained(model_name)

# # # Define your labels
# # label_map = ["Sexual Harassment", "Offensive", "Violence", "Harmful", "Propaganda", "Not Hateful"]

# # # Example text
# # text = "ইন্ডিয়া থেকে বলছি পাপন কে গুলি করে মারুন।শাকিব খুব ভাল প্লেয়ার।"

# # # Tokenize input
# # inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)

# # # Forward pass
# # with torch.no_grad():
# #     outputs = model(**inputs)

# # # Get predicted label
# # predicted_class = torch.argmax(outputs.logits, dim=-1).item()
# # predicted_label = label_map[predicted_class]

# # print(f"Predicted Label: {predicted_label}")

# %%
def generate_ai_label(statement, context):

    label_set = ["Hateful", "Not Hateful"]
    #6 labels:
    # "Sexual Harassments", "Offensive" "Violence", "Harmful", "Propaganda", "Not Hateful"
    #5 labels:
    #"Sexual Harassments", "Violence", "Harmful", "Propaganda", "Not Hateful"
    #4 labels:
    #"Sexual Harassments", "Violence", "Harmful", "Not Hateful"
    #3 labels:
    #"Sexual Harassments", "Violence", "Not Hateful"
    #2 labels:
    #"Hateful" and "Not Hateful"
    prompt = f"You are an expert Hate Speech annotator in Bengali with an identity of {context}. Annotate the following text: [{statement}] with only one best-suited label from the label set {label_set} with no explanation. Don't give any output which is not in the label set. Don't left any query blank rather give one output that seems best to you."


    
    # response = model.generate_content(messages)
    # rr = response.candidates[0].content.parts[0].text.strip()
    #selected_labels = [label for label in rr if label in label_set]
    #openai.chat.completions.create
    response = llama.run({
        "messages":[ 
            { "role": "system", "content": "You are a helpful assistant. You are a classifier that outputs only one label for a given statement." },
            { "role": "user", "content": prompt }
        ], 
        #model = "llama3-70b-8192",
        "model" : "llama3.1-70b",
        "max_tokens":10,  
        "temperature":0,  
        "top_p":1.0, }
        #top_k=2,  
        #echo=False
    )

    # inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True)

    # # Forward pass
    # with torch.no_grad():
    #     outputs = model(**inputs)

    # # Get predicted label
    # predicted_class = torch.argmax(outputs.logits, dim=-1).item()
    # predicted_label = label_set[predicted_class]

    #print(response)
    # response_text = response.choices[0].message.content.strip()
    # response_text = response_text.lower()
    response_json = response.json()
    rr = response_json["choices"][0]["message"]["content"]
    #print(response_json["output"])
    #print(respone_json["content"])
    #print(response_json["generated_text"])
    #print(response_json["message"])
    print(rr)
   
    # if "not hateful" in rr:
    #     label = "Not Hateful"
    # elif "hateful" in rr:
    #     label = "Hateful"
    # else:
    #     label = None
    #print(rr)
    return rr


def generate_ai_label_palm_with_row(statement, context, row_number):
    print(f"Processing row {row_number} with statement: {statement}")
    return generate_ai_label(statement, context)


def generate_ai_label_palm_with_retry(statement, context, row_number, retries=1, delay=3):
    for attempt in range(retries):
        try:
            return generate_ai_label_palm_with_row(statement, context, row_number)
        except InternalServerError as e:
           
            print(f"Internal server error encountered: {str(e)}")
            if attempt < retries - 1:
                backoff_time = delay * (2)  
                print(f"Retrying in {backoff_time} seconds...")
                time.sleep(backoff_time)
            else:
                print("Max retries reached. Unable to complete the request.")
                return "Error"
        except Exception as e:
           
            print(f"An unexpected error occurred: {str(e)}")
            return "Error"

# %%
df.loc[0:1001, 'Plitical Personality_biased Label'] = df.loc[0:1001].apply(
    lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "Political personality", row.name), axis=1
)
df.loc[0:1001, 'NonPlitical Personality_biased Label'] = df.loc[0:1001].apply(
    lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "NonPolitical personality", row.name), axis=1
)

# # Save the updated DataFrame back to the CSV file
df.to_csv('/kaggle/working/BanglaHateSpeech_Deep-Seek-R1 8B (2 labels).csv', index=False)

# %%
# # Define specific index ranges
# index_ranges = [
#     (0, 100), (500, 600), (1000, 1100), (1600, 1700),
#     (2200, 2300), (2800, 2900), (3100, 3200),
#     (3900, 4000), (4200, 4300), (4600, 4700)
# ]

# # Define label categories and corresponding context
# columns_with_context = {
#     'Female_biased': "gender Female",
#     'Not Female_biased': "gender Not Female",

#     # Entertainment Professions
#     'Artist_biased Label': "profession Artist",
#     'Not Artist_biased Label': "profession Not Artist",
#     'Sportsman_biased Label': "profession Sportsman",
#     'Not Sports_biased Label': "profession Not Sportsman",
#     'Vlogger_biased Label': "profession Vlogger",
#     'Not Vlogger_biased Label': "profession Not Vlogger",

#     # # # Religion
#     'Muslim_biased Label': "religion Muslim",
#     'Hindu_biased Label': "religion Hindu",
#     'Not Muslim and Hindu': "religion without Muslim and Hindu",

#     # Geopolitics
#     'Diplomacy_biased Label': "working domain Diplomacy",
#     'Not Diplomacy_biased Label': "working domain Not Diplomacy",
#     'Security_Analyst_biased Label': "working domain Security Analyst",
#     'Not Security_Analyst_biased Label': "working domain Not Security Analyst",
#     'Journalist_biased Label': "working domain Journalist",
#     'Not Journalist_biased Label': "working domain Not Journalist",

#     # Politics
#     'Plitical Personality_biased Label': "Political personality",
#     'NonPlitical Personality_biased Label': "NonPolitical personality",
#     'International Relation Analyst_biased Label': "International Relation Analyst",
#     'Not International Relation Analyst_biased Label': "Not International Relation Analyst"
# }

# # Iterate over each specified index range
# for start, end in index_ranges:
#     for column, context in columns_with_context.items():
#         df.loc[start:end, column] = df.loc[start:end].apply(
#             lambda row: generate_ai_label_palm_with_retry(row.iloc[0], context, row.name), axis=1
#         )
# df.to_csv('/kaggle/working/BanglaHateSpeech_deepseek-8B.csv', index=False)

# %%
# # Gender
# df.loc[400:500, 'Female_biased'] = df.loc[400:500].apply(
#     lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "gender Female", row.name), axis=1
# )

# df.loc[400:500, 'Not Female_biased'] = df.loc[400:500].apply(
#     lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "gender Not Female", row.name), axis=1
# )

# df['Female_biased'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "gender Female", row.name), axis=1)
# df['Not Female_biased'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "gender Not Female", row.name), axis=1)



# # ## Entertainment
# df['Artist_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "profession Artist", row.name), axis=1)
# df['Not Artist_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "profession Not Artist", row.name), axis=1)
# df['Sportsman_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "profession Sportsman", row.name), axis=1)
# df['Not Sports_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "profession Not Sportsman", row.name), axis=1)
# df['Vlogger_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "profession Vlogger", row.name), axis=1)
# df['Not Vlogger_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "profession Not Vlogger", row.name), axis=1)

# # # # Religion
# df['Muslim_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "religion Muslim", row.name), axis=1)
# df['Hindu_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "religion Hindu", row.name), axis=1)
# df['Not Muslim and Hindu'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "religion without Muslim and Hindu", row.name), axis=1)


# ##Geopolitics
# df['Diplomacy_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "working domain Diplomacy", row.name), axis=1)
# df['Not Diplomacy_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "working domain Not Diplomacy", row.name), axis=1)
# df['Security_Analyst_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "working domain Security Analyst", row.name), axis=1)
# df['Not Security_Analyst_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "working domain Not Security Analyst", row.name), axis=1)
# df['Journalist_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "working domain Journalist", row.name), axis=1)
# df['Not Journalist_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "working domain Not Journalist", row.name), axis=1)

# # # #Politics
# df['Plitical Personality_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "Political personality", row.name), axis=1)
# df['NonPlitical Personality_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "NonPolitical personality", row.name), axis=1)
# df['International Relation Analyst_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "International Relation Analyst", row.name), axis=1)
# df['Not International Relation Analyst_biased Label'] = df.apply(lambda row: generate_ai_label_palm_with_retry(row.iloc[0], "Not International Relation Analyst", row.name), axis=1)

# # Save the updated DataFrame back to the CSV file
#df.to_csv('/kaggle/working/BanglaHateSpeech_gemma2-9b_Gender.csv', index=False)   # Save as a new file or overwrite the original

# # print("Labels generated and saved to the CSV file successfully.")

# %%
# for index, row in df.iterrows():
#     if row['Female_biased'] in ["Error", "None","error"] or pd.isna(row['Female_biased']):
#         statement = row['comment']
#         new_label = generate_ai_label_palm_with_retry(statement, 'gender Female', index)
#         df.at[index, 'Female_biased'] = new_label 

# print("Female part completed")
        
# for index, row in df.iterrows():
#     if row['Mental_Disability'] in ["Error", "None","error"] or pd.isna(row['Mental_Disability']):
#         statement = row['comment']
#         new_label = generate_ai_label_palm_with_retry(statement, 'Mental Disability', index)
#         df.at[index, 'Mental_Disability'] = new_label 

# print("Mental Disability part completed")


# for index, row in df.iterrows():
#     if row['Physical_Disability'] in ["Error", "None","error"] or pd.isna(row['Physical_Disability']):
#         statement = row['comment']
#         new_label = generate_ai_label_palm_with_retry(statement, 'Physical Disability', index)
#         df.at[index, 'Physical_Disability'] = new_label  

# print("Physical Disability part completed")

        
# for index, row in df.iterrows():
#     if row['Asian_biased'] in ["Error", "None","error"] or pd.isna(row['Asian_biased']):
#         statement = row['comment']
#         new_label = generate_ai_label_palm_with_retry(statement, 'race Asian', index)
#         df.at[index, 'Asian_biased'] = new_label  
# print("Asian part completed")


# for index, row in df.iterrows():
#     if row['Black_biased'] in ["Error", "None","error"] or pd.isna(row['Black_biased']):
#         statement = row['comment']
#         new_label = generate_ai_label_palm_with_retry(statement, 'race Black', index)
#         df.at[index, 'Black_biased'] = new_label  

# print("Black part completed")


# for index, row in df.iterrows():
#     if row['Muslim_biased'] in ["Error", "None","error"] or pd.isna(row['Muslim_biased']):
#         statement = row['comment']
#         new_label = generate_ai_label_palm_with_retry(statement, 'religion Muslim', index)
#         df.at[index, 'Muslim_biased'] = new_label      

# print("Muslim part completed")

        
# df.to_csv('/kaggle/working/Llama_predicted Updated_2nd_Ethos_Corpus.csv', index=False)  

# print("Labels generated and saved to the CSV file successfully.")
